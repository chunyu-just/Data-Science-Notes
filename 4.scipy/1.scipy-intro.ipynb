# %%
import numpy as np
import pylab as pl

# %%
import matplotlib as mpl
mpl.rcParams['font.sans-serif'] = ['SimHei']
mpl.rcParams['axes.unicode_minus']=False

# %% [markdown]
# # SciPy-数值计算库

# %%
import scipy
scipy.__version__
# Out:
# '1.5.0'

# %% [markdown]
# ## 常数和特殊函数

# %%
from scipy import constants as C
print (C.c) # 真空中的光速
print (C.h) # 普朗克常数
# Out:
# 299792458.0
# 6.62607015e-34

# %%
C.physical_constants["electron mass"]
# Out:
# (9.1093837015e-31, 'kg', 2.8e-40)

# %%
# 1英里等于多少米, 1英寸等于多少米, 1克等于多少千克, 1磅等于多少千克
print(C.mile)
print(C.inch)
print(C.gram)
print(C.pound)
# Out:
# 1609.3439999999998
# 0.0254
# 0.001
# 0.45359236999999997

# %%
import scipy.special as S

# %%
print (1 + 1e-20)
print (np.log(1+1e-20))
print (S.log1p(1e-20))
# Out:
# 1.0
# 0.0
# 1e-20

# %%
m = np.linspace(0.1, 0.9, 4)
u = np.linspace(-10, 10, 200)
results = S.ellipj(u[:, None], m[None, :])
# 通过试用None增加原始数组的维度，增加的维度取决于None出现的位置
print([y.shape for y in results])
# Out:
# [(200, 4), (200, 4), (200, 4), (200, 4)]

# %%
#%figonly=使用广播计算得到的`ellipj()`返回值
fig, axes = pl.subplots(2, 2, figsize=(12, 4))
labels = ["$sn$", "$cn$", "$dn$", "$\phi$"]
for ax, y, label in zip(axes.ravel(), results, labels): # 结合ravel()函数列出所有子图
    ax.plot(u, y)
    ax.set_ylabel(label)
    ax.margins(0, 0.1)
    
axes[1, 1].legend(["$m={:g}$".format(m_) for m_ in m], loc="best", ncol=2);
